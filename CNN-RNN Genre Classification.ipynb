# %% [markdown]
# #### Student Name: Vivian
# #### Student ID: A17442498

# %% [markdown]
# # Assignment 8
#
# #### Parallel CNN - RNN Model
#
# Instructions:
#
# * This notebook is an interactive assignment; please read and follow the instructions in each cell.
#
# * Cells that require your input (in the form of code or written response) will have 'Question #' above.
#
# * After completing the assignment, please submit this notebook and a printout as a PDF.

# %% [markdown]
# # Let's try using a neural networks to classify audio genres

# %% [markdown]
# ## Your Task:
#
# In this Assignment we will explore the use of CNN-RNN for genre classification. You are provided some code as usual, and are asked to fill in missing portions and perform some experiments.
#
# The main tasks are:
# * specifying the parameters of the CNN model
# * you are provided with the code of the RNN model
# * conducting an experiment with CNN-RNN model
# * visualizing the preformance of the CNN layers
# * performing ablation study by comparing it to only CNN and only RNN model

# %% [markdown]
# ### Import packages

# %%
# %pip install keract
# %pip install "protobuf==3.20.3"
# %pip install librosa
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#   Using cached librosa-0.11.0-py3-none-any.whl.metadata (8.7 kB)
# ...
#   Using cached audioread-3.0.1-py3-none-any.whl.metadata (8.4 kB)
# ...
#   Using cached soundfile-0.13.1-py2.py3-none-win_amd64.whl.metadata (16 kB)
# ...
#   Using cached pooch-1.8.2-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached lazy_loader-0.4-py3-none-any.whl.metadata (7.6 kB)
# ...
#   Using cached pycparser-2.22-py3-none-any.whl.metadata (943 bytes)
# Using cached librosa-0.11.0-py3-none-any.whl (260 kB)
# Using cached audioread-3.0.1-py3-none-any.whl (23 kB)
# Using cached lazy_loader-0.4-py3-none-any.whl (12 kB)
# ...

# %%
import numpy as np
import os
from os.path import isfile
import keras
from keras.models import Sequential, Model
from keras.layers import Input, Dense, Bidirectional, LSTM, Dropout, Activation, GRU
from keras.layers import Conv2D, concatenate, MaxPooling2D, Flatten, Embedding, Lambda


from keras.callbacks import ModelCheckpoint, TensorBoard, ReduceLROnPlateau
from keras import backend as K
from tensorflow.keras.optimizers import RMSprop

from keras import regularizers


import librosa
import librosa.display
import matplotlib.pyplot as plt
# %matplotlib inline

import keract

# %% [markdown]
# ### Define representation of genres
#
# Each genre is assigned a number, since the neural network will output a number [not a word].

# %%
dict_genres = {'Electronic': 0, 'Experimental': 1, 'Folk': 2, 'Hip-Hop': 3, 
               'Instrumental': 4,'International': 5, 'Pop': 6, 'Rock': 7}


reverse_map = {v: k for k, v in dict_genres.items()}
print(reverse_map)
# Out:
# {0: 'Electronic', 1: 'Experimental', 2: 'Folk', 3: 'Hip-Hop', 4: 'Instrumental', 5: 'International', 6: 'Pop', 7: 'Rock'}

# %% [markdown]
# ### Load the dataset

# %% [markdown]
# The dataset can be found at https://drive.google.com/drive/folders/1ZtwC9ralBSs6wzP-IylX5uh1wD1YXLh9?usp=sharing
#
# Instructions: you can manually download it to your computer, or use wget from a command line. \
# If you are using colab, you can copy the files to your drive and then mount the drive using google colab drive command: \
# from google.colab import drive \
# drive.mount('/content/drive')

# %%
npzfile = np.load('shuffled_train.npz')

X_train = npzfile['arr_0']   # Audio samples
y_train = npzfile['arr_1']   # Genre labels
print(X_train.shape, y_train.shape)
# Out:
# (6394, 640, 128) (6394, 8)

# %%
npzfile = np.load('shuffled_valid.npz')

X_valid = npzfile['arr_0']
y_valid = npzfile['arr_1']
print(X_valid.shape, y_valid.shape)
# Out:
# (800, 640, 128) (800, 8)

# %% [markdown]
# ### Let's see what one data sample looks like:

# %%
one_arbitrary_sample = 0
spectogram = X_train[one_arbitrary_sample]
genre = np.argmax(y_train[one_arbitrary_sample])
print(reverse_map[genre])     # Reverse Map: Number to Label

plt.figure(figsize=(10, 5))
librosa.display.specshow(spectogram.T, y_axis='mel', x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('Test Melspectogram')
plt.tight_layout()
# Out:
# Electronic

# %% [markdown]
# ##### Question 1 (20 points)

# %% [markdown]
# Create a few mel-spectograms samples for each genre. What are some visual differences between the genres? Are there similarities? What are some unique features for each genre that we might be able to use for classification?

# %%
import numpy as np
import matplotlib.pyplot as plt
import librosa.display
import os

# load
train_npz = np.load(r'C:\Users\vivia\OneDrive\Documents\GitHub\ML4Music-HW\shuffled_train.npz', allow_pickle=True)
X_train = train_npz['arr_0']
y_train = train_npz['arr_1']
valid_npz = np.load('shuffled_valid.npz', allow_pickle=True)
X_valid = valid_npz['arr_0']
y_valid = valid_npz['arr_1']

# reverse_map: index -> genre name; replace with your real labels
genre_names = ["Electronic", "Experimental", "Folk", "Hip-Hop", "Instrumental"]
reverse_map = {i: name for i, name in enumerate(genre_names)}

def plot_samples_by_genre_with_labels(X, y, reverse_map, samples_per_genre=3, dataset_name="train"):
    # collect indices per genre
    genre_to_indices = {}
    for idx in range(len(y)):
        genre_idx = int(np.argmax(y[idx]))
        genre_to_indices.setdefault(genre_idx, []).append(idx)

    num_genres = len(sorted(genre_to_indices.keys()))
    fig, axes = plt.subplots(num_genres, samples_per_genre, figsize=(4 * samples_per_genre, 3 * num_genres), squeeze=False)

    for row, genre_idx in enumerate(sorted(genre_to_indices.keys())):
        label = reverse_map.get(genre_idx, f"class_{genre_idx}")
        indices = genre_to_indices[genre_idx][:samples_per_genre]
        # print what is being shown for this genre
        print(f"{dataset_name.capitalize()} - Genre '{label}' (index {genre_idx}): showing samples {indices}")
        for col in range(samples_per_genre):
            ax = axes[row, col]
            if col < len(indices):
                spec = X[indices[col]]
                librosa.display.specshow(spec.T, y_axis='mel', x_axis='time', ax=ax)
                ax.set_title(f"{label} #{indices[col]}")
                if col == 0:
                    ax.set_ylabel(label)
            else:
                ax.axis('off')
    plt.suptitle(f"{dataset_name.capitalize()} set: {samples_per_genre} examples per genre", fontsize=16, y=1.02)
    plt.tight_layout()
    plt.show()

# Use it
plot_samples_by_genre_with_labels(X_train, y_train, reverse_map, samples_per_genre=3, dataset_name="train")
plot_samples_by_genre_with_labels(X_valid, y_valid, reverse_map, samples_per_genre=3, dataset_name="valid")
# Out:
# Train - Genre 'Electronic' (index 0): showing samples [0, 6, 11]
# Train - Genre 'Experimental' (index 1): showing samples [1, 5, 18]
# Train - Genre 'Folk' (index 2): showing samples [9, 20, 26]
# Train - Genre 'Hip-Hop' (index 3): showing samples [13, 16, 24]
# Train - Genre 'Instrumental' (index 4): showing samples [12, 14, 19]
# Train - Genre 'class_5' (index 5): showing samples [2, 3, 10]
# Train - Genre 'class_6' (index 6): showing samples [4, 17, 23]
# Train - Genre 'class_7' (index 7): showing samples [7, 8, 42]
# Valid - Genre 'Electronic' (index 0): showing samples [2, 16, 33]
# Valid - Genre 'Experimental' (index 1): showing samples [0, 12, 26]
# Valid - Genre 'Folk' (index 2): showing samples [14, 18, 20]
# Valid - Genre 'Hip-Hop' (index 3): showing samples [3, 4, 7]
# Valid - Genre 'Instrumental' (index 4): showing samples [6, 8, 17]
# Valid - Genre 'class_5' (index 5): showing samples [1, 5, 13]
# Valid - Genre 'class_6' (index 6): showing samples [22, 27, 31]
# ...

# %% [markdown]
# ``` Your response here ``` The mel-spectrograms reveal clear patterns that can help distinguish genres,  electronic and hip-hop show strong rhythmic onsets with prominent low-frequency energy (hip-hop often with more humanized beats), folk and instrumental exhibit stable harmonic structures and midrange emphasis, and experimental is more variable and texture-heavy with high spectral entropy and irregular rhythms. Similarities like rhythmic content in electronic vs. hip-hop or acoustic-like qualities in folk vs. some instrumental samples mean careful feature selection is needed.

# %% [markdown]
# ### Convolution Layer
#
# A convolution is a kernel (a matrix of weights; also reffered to as a mask) that is applied across an image to extract spatial information by factoring each point's neighbors.
#
# Classical image processing uses custom kernels that can extract key features that can be used for problems like edge detection. Refer to this Wiki article for a few examples.
# https://en.wikipedia.org/wiki/Kernel_(image_processing)
#
# In deep learning, we build a model to learn more complicated kernels that can extract more specialized information.

# %% [markdown]
# ![convolution_gif.gif](data:image/gif;base64,...)

# %% [markdown]
# ##### Question 2 (10 points)

# %% [markdown]
# Given a convolution layer with $f$ filters, ($k_x$ x $k_y$) kernel, and ($s_x$ x $s_y$) stride, what is the output dimension with/without padding (ie "valid" vs "same") on an ($n_x$ x $n_y$) image?
#
# Please refer to the official keras documentation (https://keras.io/api/layers/convolution_layers/convolution2d/)

# %% [markdown]
# ``` Your response here ```
# Let:
# - Input size: \(n_x \times n_y\)
# - Kernel size: \(k_x \times k_y\)
# - Stride: \(s_x \times s_y\)
# - Number of filters: \(f\)
#
# ### 1. Valid padding (no padding):
# \[
# \text{out}_x = \left\lfloor \frac{n_x - k_x}{s_x} \right\rfloor + 1,\quad
# \text{out}_y = \left\lfloor \frac{n_y - k_y}{s_y} \right\rfloor + 1
# \]
# Output shape (per example): \((\text{out}_x, \text{out}_y, f)\)
#
# ### 2. Same padding (as in Keras):
# Keras pads so that the output spatial size is:
# \[
# \text{out}_x = \left\lceil \frac{n_x}{s_x} \right\rceil,\quad
# \text{out}_y = \left\lceil \frac{n_y}{s_y} \right\rceil
# \]
# Output shape: \((\text{out}_x, \text{out}_y, f)\)
#
# ### 3. General formula with explicit padding \(P_x, P_y\) on each side:
# \[
# \text{out}_x = \left\lfloor \frac{n_x + 2P_x - k_x}{s_x} \right\rfloor + 1,\quad
# \text{out}_y = \left\lfloor \frac{n_y + 2P_y - k_y}{s_y} \right\rfloor + 1
# \]

# %% [markdown]
# ### Pooling Layer
#
# A pool is a very similar to a convolution layer. It is filter that is applied across the output of the convolution layer to reduce dimensionality and mitigate overfitting by summarizing the convolution results.
#
# For this demonstration, we will be using max pooling.

# %% [markdown]
# ![pool_gif.gif](data:image/gif;base64,...)

# %% [markdown]
# ##### Question 3 (10 points)

# %% [markdown]
# Given a pooling layer ($p_x$ x $p_y$) pool and ($s_x$ x $s_y$) stride, what is the output dimension with/without padding (ie "valid" vs "same") on an ($n_x$ x $n_y$) image?
#
# Please refer to the official keras documentation (https://keras.io/api/layers/pooling_layers/max_pooling2d/)

# %% [markdown]
# ``` Your response here ```
#
#
# Let:
# - Input spatial size: \(n_x \times n_y\)
# - Pool size: \(p_x \times p_y\)
# - Stride: \(s_x \times s_y\)
#
# Max pooling operates per channel, so channel depth is preserved.
#
# ### 1. Valid padding (no padding):
# \[
# \text{out}_x = \left\lfloor \frac{n_x - p_x}{s_x} \right\rfloor + 1,\quad
# \text{out}_y = \left\lfloor \frac{n_y - p_y}{s_y} \right\rfloor + 1
# \]
# Output shape (per example, per channel): \((\text{out}_x, \text{out}_y)\)
#
# ### 2. Same padding (as in Keras):
# Keras pads so that the output spatial size is:
# \[
# \text{out}_x = \left\lceil \frac{n_x}{s_x} \right\rceil,\quad
# \text{out}_y = \left\lceil \frac{n_y}{s_y} \right\rceil
# \]
#
# ### 3. General formula with explicit padding \(P_x, P_y\) on each side:
# \[
# \text{out}_x = \left\lfloor \frac{n_x + 2P_x - p_x}{s_x} \right\rfloor + 1,\quad
# \text{out}_y = \left\lfloor \f_

# %% [markdown]
# ### Now we will implement our model
# #### Parallel CNN - RNN Model
#
# Since music has temporal features, it is obvious to use a RNN, but we saw from the melspectograms that there are also visual features that a CNN might learn. Our motivation is to try to combine both models through concatenation to extract both temporal and spatial features.

# %% [markdown]
# ![Model_diagram.png](data:image/png;base64,...)

# %%
# The number of possible predicted classes
num_classes = 8

# The number of features in a single data input (frequency components)
n_features = X_train.shape[2]

# The length of an input sample (in seconds)
n_time = X_train.shape[1]

# %%
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Bidirectional, GRU, Lambda, Dense, concatenate
from tensorflow.keras import backend as K
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import RMSprop

def conv_recurrent_model_build(model_input, num_classes=8):
    print('Building model...')
    layer = model_input  # expected shape: (time, freq, 1) or similar

    ### Convolutional blocks
    conv_1 = Conv2D(filters=16, kernel_size=(3,1), strides=(1,1),
                    padding='valid', activation='relu', name='conv_1')(layer)
    pool_1 = MaxPooling2D((2,2), name='pool_1')(conv_1)

    conv_2 = Conv2D(filters=32, kernel_size=(3,1), strides=(1,1),
                    padding='valid', activation='relu', name='conv_2')(pool_1)
    pool_2 = MaxPooling2D((2,2), name='pool_2')(conv_2)

    conv_3 = Conv2D(filters=64, kernel_size=(3,1), strides=(1,1),
                    padding='valid', activation='relu', name='conv_3')(pool_2)
    pool_3 = MaxPooling2D((2,2), name='pool_3')(conv_3)

    conv_4 = Conv2D(filters=128, kernel_size=(3,1), strides=(1,1),
                    padding='valid', activation='relu', name='conv_4')(pool_3)
    pool_4 = MaxPooling2D((2,2), name='pool_4')(conv_4)

    conv_5 = Conv2D(filters=256, kernel_size=(3,1), strides=(1,1),
                    padding='valid', activation='relu', name='conv_5')(pool_4)
    pool_5 = MaxPooling2D((2,2), name='pool_5')(conv_5)

    flatten1 = Flatten(name='flatten_conv')(pool_5)

    ### Recurrent Block (separate branch)
    lstm_count = 64

    # Pooling before recurrence: you used original input here
    pool_lstm1 = MaxPooling2D((4,2), name='pool_lstm')(layer)
    squeezed = Lambda(lambda x: K.squeeze(x, axis=-1), name='squeeze_lstm')(pool_lstm1)
    lstm = Bidirectional(GRU(lstm_count), name='bidir_gru')(squeezed)  # default merge is concat

    # Concatenate conv + recurrent
    concat = concatenate([flatten1, lstm], axis=-1, name='concat')

    # Output
    output = Dense(num_classes, activation='softmax', name='preds')(concat)

    model = Model(model_input, output, name='conv_recurrent')
    opt = RMSprop(learning_rate=0.0005)
    model.compile(
        loss='categorical_crossentropy',
        optimizer=opt,
        metrics=['accuracy']
    )
    return model

# %% [markdown]
# ##### Question 4 (30 points)

# %% [markdown]
# Fill in the missing code for the cell above and implement the four missing convolution layers interwoven with max pooling layers. When you run the commented-out code below, your output should match the image below. Use the first convolution and pooling layer as an example.
#
# All of the convolution layers should have the same kernel size, stride, padding, and activation function.
#
# If you are stuck, this article should help:
# https://towardsdatascience.com/how-to-calculate-the-number-of-parameters-in-keras-models-710683dae0ca

# %%
n_frequency = 128
n_frames = 640
input_shape = (n_frames, n_frequency, 1)
model_input = Input(input_shape, name='input')
model = conv_recurrent_model_build(model_input)
# Out:
# Building model...
# WARNING:tensorflow:From c:\Users\vivia\OneDrive\Documents\GitHub\ML4Music-HW\.venv\lib\site-packages\keras\src\backend\tensorflow\core.py:232: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.

# %% [markdown]
# ![assignment8_model.PNG](data:image/png;base64,...)

# %% [markdown]
# Hint: use print(model.summary()) to check if your model satisfies the requirements of the specifications above.

# %%
def train_model(x_train, y_train, x_val, y_val):
    n_frequency = 128
    n_frames = 640

    x_train = np.expand_dims(x_train, axis=-1)
    x_val = np.expand_dims(x_val, axis=-1)

    input_shape = (n_frames, n_frequency, 1)
    model_input = Input(input_shape, name='input')

    model = conv_recurrent_model_build(model_input, num_classes=num_classes)  ### Step 1

    checkpoint_callback = ModelCheckpoint(
        './models/parallel/weights.best.h5',
        monitor='val_accuracy',
        verbose=1,
        save_best_only=True,
        mode='max'
    )

    reducelr_callback = ReduceLROnPlateau(
        monitor='val_accuracy', factor=0.5, patience=10, min_delta=0.01, verbose=1
    )

    callbacks_list = [checkpoint_callback, reducelr_callback]

    # Fit the model and get training history.
    print('Training...')
    history = model.fit(
        x_train,
        y_train,
        batch_size=64,
        epochs=5,
        validation_data=(x_val, y_val),
        verbose=1,
        callbacks=callbacks_list
    )  ### Step 2

    return model, history

# %%
def show_summary_stats(history):
    # List all data in history
    print(history.history.keys())

    # Summarize history for accuracy
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

    # Summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

# %%
model, history = train_model(X_train, y_train, X_valid, y_valid)
# Out:
# Building model...
# Training...
# Epoch 1/5
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 621ms/step - accuracy: 0.2019 - loss: 2.2081
# Epoch 1: val_accuracy improved from -inf to 0.18250, saving model to ./models/parallel/weights.best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 72s 675ms/step - accuracy: 0.2023 - loss: 2.2061 - val_accuracy: 0.1825 - val_loss: 1.9293 - learning_rate: 5.0000e-04
# Epoch 2/5
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 611ms/step - accuracy: 0.3252 - loss: 1.8092
# Epoch 2: val_accuracy improved from 0.18250 to 0.32000, saving model to ./models/parallel/weights.best.h5
# ...

# %% [markdown]
# ### Results

# %%
show_summary_stats(history)
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss', 'learning_rate'])

# %%
from sklearn.metrics import classification_report

y_true = np.argmax(y_valid, axis = 1)
X_valid = np.expand_dims(X_valid, axis = -1)
y_pred = model.predict(X_valid)
y_pred = np.argmax(y_pred, axis=1)
labels = [0,1,2,3,4,5,6,7]
target_names = dict_genres.keys()

print(y_true.shape, y_pred.shape)
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 91ms/step
# (800,) (800,)
#                precision    recall  f1-score   support
#
#    Electronic       0.35      0.56      0.43       100
#  Experimental       0.27      0.28      0.27       100
#          Folk       0.58      0.56      0.57       100
#       Hip-Hop       0.59      0.44      0.50       100
#  Instrumental       0.36      0.32      0.34       100
# International       0.77      0.24      0.37       100
#           Pop       0.00      0.00      0.00       100
#          Rock       0.38      0.87      0.53       100
#
#      accuracy                           0.41       800
#     macro avg       0.41      0.41      0.38       800
#  weighted avg       0.41      0.41      0.38       800

# %% [markdown]
# ##### Question 5 (10 points)

# %% [markdown]
# Briefly describe, in a few sentences, the training results. Does the model perform well? What can we learn from the train and test loss curves? Is the model overfitted? What do the metrics tell us?
#
# *Note that you can increase the number of epochs to get a better picture of the models performance

# %% [markdown]
# ``` Your response here ```  The model is underperforming overall accuracy is only 41%, and the per-class F1 scores vary wildly. Some genres like Rock have high recall (0.87) but low precision, meaning the model over-predicts Rock, while Pop collapses entirely (zero precision/recall), and others (e.g., Electronic, Instrumental) are mediocre. This suggests strong class confusion and possibly class imbalance or insufficient discriminative power in the current representation. Without seeing the loss curves it's hard to be definitive, but if training loss is much lower than validation loss, that’d signal overfitting. if both remain high or plateau, the model may be underfitting or need more training (more epochs) / better features.

# %% [markdown]
# ### Visualizing the Model

# %%
# pick one sample and genre
one_arbitrary_sample = 0
sample = X_valid[one_arbitrary_sample:one_arbitrary_sample+1]
genre = np.argmax(y_valid[one_arbitrary_sample])
print("Genre index:", genre)
layer_names = ['conv_1', 'conv_2', 'conv_3', 'conv_4', 'conv_5']  

for name in layer_names:
    try:
        layer = model.get_layer(name)
    except ValueError:
        print(f"Layer {name} not found in model.")
        continue

    submodel = Model(inputs=model.input, outputs=layer.output)
    activation = submodel.predict(sample)  
    n_channels_to_plot = min(6, activation.shape[-1])
    fig, axes = plt.subplots(1, n_channels_to_plot, figsize=(3 * n_channels_to_plot, 3))
    fig.suptitle(f"Activations from layer {name} (first {n_channels_to_plot} channels)")

    act = activation[0]
    for i in range(n_channels_to_plot):
        ax = axes[i]
        img = act[..., i]  
        im = ax.imshow(img.T, origin='lower', aspect='auto')
        ax.set_title(f"ch {i}")
        ax.axis('off')
    fig.colorbar(im, ax=axes, fraction=0.046, pad=0.04)
    plt.tight_layout()
    plt.show()
# Out:
# Genre index: 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# C:\Users\vivia\AppData\Local\Temp\ipykernel_18020\4143971479.py:38: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# ...

# %% [markdown]
# ##### Question 6 (20 points)
# Visualize the activation layers for the CNN using the code above and try a few samples for each genre. Are there any clear features? Are any of the features similar to the features you expected at the start? Are there similar or different features across genres?

# %% [markdown]
# ``` Your response here ``` Those activation visualizations are doing exactly what you’d hope the early conv layers  preserve much of the raw spectro-temporal structure—you can still see vertical streaks  and horizontal smearing  in different channels—matching your initial expectations about detecting rhythm and timbre. As you go deeper (conv_3–conv_5), the representations become sparser and more selective some channels “light up” only for particular patterns while others are nearly silent, suggesting the network is learning specialized detectors  Across genres, you’d expect strong rhythmic genres like hip-hop or electronic to induce consistent vertical activations in certain channels, whereas harmonic-rich genres like folk/instrumental would activate channels that reflect more stable horizontal structure.The activations align with your expected features while showing the model’s internal specialization emerging through depth.
